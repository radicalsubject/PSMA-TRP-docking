# %%
# !conda install jupyter schrodinger::pymol -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/vina
#
#   added / updated specs:
#     - jupyter
#     - schrodinger::pymol
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |           1_llvm           5 KB  conda-forge
#     alsa-lib-1.2.3             |       h516909a_0         560 KB  conda-forge
#     brotlipy-0.7.0             |py38h497a2fe_1001         341 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.17.2              |       h7f98852_0         109 KB  conda-forge
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     certifi-2021.5.30          |   py38h578d9bd_0         141 KB  conda-forge
#     chardet-4.0.0              |   py38h578d9bd_1         199 KB  conda-forge
#     charset-normalizer-2.0.0   |     pyhd8ed1ab_0          32 KB  conda-forge
#     cryptography-3.4.7         |   py38ha5dfef3_0         1.1 MB  conda-forge
#     curl-7.79.1                |       h2574ce0_1         153 KB  conda-forge
#     dbus-1.13.6                |       h48d8840_2         572 KB  conda-forge
#     expat-2.4.1                |       h9c3ff4c_0         182 KB  conda-forge
#     fontconfig-2.13.1          |    hba837de_1005         357 KB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     gettext-0.19.8.1           |    h0b5b191_1005         3.6 MB  conda-forge
#     glew-2.1.0                 |       h9c3ff4c_2         647 KB  conda-forge
#     glib-2.68.4                |       h9c3ff4c_0         447 KB  conda-forge
#     glib-tools-2.68.4          |       h9c3ff4c_0          86 KB  conda-forge
#     gst-plugins-base-1.18.5    |       hf529b03_0         2.6 MB  conda-forge
#     gstreamer-1.18.5           |       h76c114f_0         2.0 MB  conda-forge
#     h5py-3.2.1                 |nompi_py38h9915d05_100         1.4 MB  conda-forge
#     hdf4-4.2.15                |       h10796ff_3         950 KB  conda-forge
#     hdf5-1.10.6                |nompi_h7c3c948_1111         3.1 MB  conda-forge
#     idna-3.1                   |     pyhd3deb0d_0          52 KB  conda-forge
#     ipywidgets-7.6.5           |     pyhd8ed1ab_0         101 KB  conda-forge
#     jbig-2.1                   |    h7f98852_2003          43 KB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
#     jupyter-1.0.0              |   py38h578d9bd_6           6 KB  conda-forge
#     jupyter_console-6.4.0      |     pyhd8ed1ab_0          22 KB  conda-forge
#     jupyterlab_widgets-1.0.2   |     pyhd8ed1ab_0         130 KB  conda-forge
#     krb5-1.19.2                |       hcc1bbae_2         1.4 MB  conda-forge
#     lcms2-2.12                 |       hddcbb42_0         443 KB  conda-forge
#     lerc-2.2.1                 |       h9c3ff4c_0         213 KB  conda-forge
#     libblas-3.9.0              |       8_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |       8_openblas          11 KB  conda-forge
#     libclang-11.1.0            |default_ha53f305_1        19.2 MB  conda-forge
#     libcurl-7.79.1             |       h2574ce0_1         335 KB  conda-forge
#     libdeflate-1.7             |       h7f98852_5          67 KB  conda-forge
#     libedit-3.1.20191231       |       he28a2e2_2         121 KB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libevent-2.1.10            |       h9b69904_4         1.1 MB  conda-forge
#     libgcc-ng-11.2.0           |       h1d223b6_9         889 KB  conda-forge
#     libgfortran-ng-7.5.0       |      h14aa051_19          22 KB  conda-forge
#     libgfortran4-7.5.0         |      h14aa051_19         1.3 MB  conda-forge
#     libglib-2.68.4             |       h3e27bee_0         3.0 MB  conda-forge
#     libglu-9.0.0               |    he1b5a44_1001         413 KB  conda-forge
#     libholoplaycore-0.1.0_rc4  |                1         325 KB  schrodinger
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     liblapack-3.9.0            |       8_openblas          11 KB  conda-forge
#     libllvm11-11.1.0           |       hf817b99_2        29.1 MB  conda-forge
#     libnetcdf-4.8.1            |nompi_hcd642e3_100         1.4 MB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_1         790 KB  conda-forge
#     libogg-1.3.4               |       h7f98852_1         206 KB  conda-forge
#     libopenblas-0.3.12         |pthreads_hb3c22a3_1         8.2 MB  conda-forge
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libpq-13.3                 |       hd57d9b9_0         2.7 MB  conda-forge
#     libssh2-1.10.0             |       ha56f1ee_2         233 KB  conda-forge
#     libstdcxx-ng-11.2.0        |       he4da1e4_9         4.2 MB  conda-forge
#     libtiff-4.3.0              |       hf544144_1         668 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     libwebp-base-1.2.1         |       h7f98852_0         845 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1003         395 KB  conda-forge
#     libxkbcommon-1.0.3         |       he3ba5ed_0         581 KB  conda-forge
#     libxml2-2.9.12             |       h72842e0_0         772 KB  conda-forge
#     libzip-1.8.0               |       h4de3113_1         126 KB  conda-forge
#     llvm-openmp-12.0.1         |       h4bd325d_1         2.8 MB  conda-forge
#     lz4-c-1.9.3                |       h9c3ff4c_1         179 KB  conda-forge
#     mtz2ccp4_px-1.0            |       h9ac9557_3         547 KB  schrodinger
#     mysql-common-8.0.25        |       ha770c72_2         1.6 MB  conda-forge
#     mysql-libs-8.0.25          |       hfa10184_2         1.8 MB  conda-forge
#     nspr-4.30                  |       h9c3ff4c_0         233 KB  conda-forge
#     nss-3.69                   |       hb5efdd6_1         2.1 MB  conda-forge
#     numpy-1.21.2               |   py38he2449b9_0         6.2 MB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     openjpeg-2.4.0             |       hb52868f_1         444 KB  conda-forge
#     openssl-1.1.1l             |       h7f98852_0         2.1 MB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     pillow-8.3.2               |   py38h8e6f84c_0         693 KB  conda-forge
#     pmw-2.0.1                  |py38h578d9bd_1004         496 KB  conda-forge
#     prompt_toolkit-3.0.20      |       hd8ed1ab_0           4 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pymol-2.5.2                |   py38hffc77be_0         9.2 MB  schrodinger
#     pyopenssl-21.0.0           |     pyhd8ed1ab_0          48 KB  conda-forge
#     pyqt-5.12.3                |   py38h578d9bd_7          21 KB  conda-forge
#     pyqt-impl-5.12.3           |   py38h7400c14_7         5.9 MB  conda-forge
#     pyqt5-sip-4.19.18          |   py38h709712a_7         310 KB  conda-forge
#     pyqtchart-5.12             |   py38h7400c14_7         257 KB  conda-forge
#     pyqtwebengine-5.12.1       |   py38h7400c14_7         175 KB  conda-forge
#     pysocks-1.7.1              |   py38h578d9bd_3          27 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     qt-5.12.9                  |       hda022c4_4        99.5 MB  conda-forge
#     qtconsole-5.1.1            |     pyhd8ed1ab_0          89 KB  conda-forge
#     qtpy-1.11.2                |     pyhd8ed1ab_0          37 KB  conda-forge
#     requests-2.26.0            |     pyhd8ed1ab_0          52 KB  conda-forge
#     rigimol-1.3                |                2         489 KB  schrodinger
#     urllib3-1.26.7             |     pyhd8ed1ab_0         100 KB  conda-forge
#     vtk-m-1.5.1                |       hf484d3e_1         4.8 MB  schrodinger
#     widgetsnbextension-3.5.1   |   py38h578d9bd_4         1.8 MB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libx11-1.7.2          |       h7f98852_0         941 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h7f98852_1          54 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h7f98852_1002          28 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     zstd-1.5.0                 |       ha95c52a_0         490 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       245.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.3-h516909a_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py38h497a2fe_1001
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.17.2-h7f98852_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   chardet            conda-forge/linux-64::chardet-4.0.0-py38h578d9bd_1
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.0.0-pyhd8ed1ab_0
#   cryptography       conda-forge/linux-64::cryptography-3.4.7-py38ha5dfef3_0
#   curl               conda-forge/linux-64::curl-7.79.1-h2574ce0_1
#   dbus               conda-forge/linux-64::dbus-1.13.6-h48d8840_2
#   expat              conda-forge/linux-64::expat-2.4.1-h9c3ff4c_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-hba837de_1005
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   glew               conda-forge/linux-64::glew-2.1.0-h9c3ff4c_2
#   glib               conda-forge/linux-64::glib-2.68.4-h9c3ff4c_0
#   glib-tools         conda-forge/linux-64::glib-tools-2.68.4-h9c3ff4c_0
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.18.5-hf529b03_0
#   gstreamer          conda-forge/linux-64::gstreamer-1.18.5-h76c114f_0
#   h5py               conda-forge/linux-64::h5py-3.2.1-nompi_py38h9915d05_100
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h10796ff_3
#   hdf5               conda-forge/linux-64::hdf5-1.10.6-nompi_h7c3c948_1111
#   idna               conda-forge/noarch::idna-3.1-pyhd3deb0d_0
#   ipywidgets         conda-forge/noarch::ipywidgets-7.6.5-pyhd8ed1ab_0
#   jbig               conda-forge/linux-64::jbig-2.1-h7f98852_2003
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   jupyter            conda-forge/linux-64::jupyter-1.0.0-py38h578d9bd_6
#   jupyter_console    conda-forge/noarch::jupyter_console-6.4.0-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-1.0.2-pyhd8ed1ab_0
#   krb5               conda-forge/linux-64::krb5-1.19.2-hcc1bbae_2
#   lcms2              conda-forge/linux-64::lcms2-2.12-hddcbb42_0
#   lerc               conda-forge/linux-64::lerc-2.2.1-h9c3ff4c_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-8_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-8_openblas
#   libclang           conda-forge/linux-64::libclang-11.1.0-default_ha53f305_1
#   libcurl            conda-forge/linux-64::libcurl-7.79.1-h2574ce0_1
#   libdeflate         conda-forge/linux-64::libdeflate-1.7-h7f98852_5
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-he28a2e2_2
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libevent           conda-forge/linux-64::libevent-2.1.10-h9b69904_4
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-7.5.0-h14aa051_19
#   libgfortran4       conda-forge/linux-64::libgfortran4-7.5.0-h14aa051_19
#   libglib            conda-forge/linux-64::libglib-2.68.4-h3e27bee_0
#   libglu             conda-forge/linux-64::libglu-9.0.0-he1b5a44_1001
#   libholoplaycore    schrodinger/linux-64::libholoplaycore-0.1.0_rc4-1
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-8_openblas
#   libllvm11          conda-forge/linux-64::libllvm11-11.1.0-hf817b99_2
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.8.1-nompi_hcd642e3_100
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_1
#   libogg             conda-forge/linux-64::libogg-1.3.4-h7f98852_1
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.12-pthreads_hb3c22a3_1
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libpq              conda-forge/linux-64::libpq-13.3-hd57d9b9_0
#   libssh2            conda-forge/linux-64::libssh2-1.10.0-ha56f1ee_2
#   libtiff            conda-forge/linux-64::libtiff-4.3.0-hf544144_1
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.1-h7f98852_0
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1003
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.0.3-he3ba5ed_0
#   libxml2            conda-forge/linux-64::libxml2-2.9.12-h72842e0_0
#   libzip             conda-forge/linux-64::libzip-1.8.0-h4de3113_1
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-12.0.1-h4bd325d_1
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_1
#   mtz2ccp4_px        schrodinger/linux-64::mtz2ccp4_px-1.0-h9ac9557_3
#   mysql-common       conda-forge/linux-64::mysql-common-8.0.25-ha770c72_2
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.0.25-hfa10184_2
#   nspr               conda-forge/linux-64::nspr-4.30-h9c3ff4c_0
#   nss                conda-forge/linux-64::nss-3.69-hb5efdd6_1
#   numpy              conda-forge/linux-64::numpy-1.21.2-py38he2449b9_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hb52868f_1
#   pcre               conda-forge/linux-64::pcre-8.45-h9c3ff4c_0
#   pillow             conda-forge/linux-64::pillow-8.3.2-py38h8e6f84c_0
#   pmw                conda-forge/linux-64::pmw-2.0.1-py38h578d9bd_1004
#   prompt_toolkit     conda-forge/noarch::prompt_toolkit-3.0.20-hd8ed1ab_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pymol              schrodinger/linux-64::pymol-2.5.2-py38hffc77be_0
#   pyopenssl          conda-forge/noarch::pyopenssl-21.0.0-pyhd8ed1ab_0
#   pyqt               conda-forge/linux-64::pyqt-5.12.3-py38h578d9bd_7
#   pyqt-impl          conda-forge/linux-64::pyqt-impl-5.12.3-py38h7400c14_7
#   pyqt5-sip          conda-forge/linux-64::pyqt5-sip-4.19.18-py38h709712a_7
#   pyqtchart          conda-forge/linux-64::pyqtchart-5.12-py38h7400c14_7
#   pyqtwebengine      conda-forge/linux-64::pyqtwebengine-5.12.1-py38h7400c14_7
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py38h578d9bd_3
#   python_abi         conda-forge/linux-64::python_abi-3.8-2_cp38
#   qt                 conda-forge/linux-64::qt-5.12.9-hda022c4_4
#   qtconsole          conda-forge/noarch::qtconsole-5.1.1-pyhd8ed1ab_0
#   qtpy               conda-forge/noarch::qtpy-1.11.2-pyhd8ed1ab_0
#   requests           conda-forge/noarch::requests-2.26.0-pyhd8ed1ab_0
#   rigimol            schrodinger/linux-64::rigimol-1.3-2
#   urllib3            conda-forge/noarch::urllib3-1.26.7-pyhd8ed1ab_0
#   vtk-m              schrodinger/linux-64::vtk-m-1.5.1-hf484d3e_1
#   widgetsnbextension conda-forge/linux-64::widgetsnbextension-3.5.1-py38h578d9bd_4
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.2-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   zstd               conda-forge/linux-64::zstd-1.5.0-ha95c52a_0
#
# The following packages will be REMOVED:
#
#   libgomp-9.3.0-h5101ec6_17
#
# The following packages will be UPDATED:
#
#   libgcc-ng          pkgs/main::libgcc-ng-9.3.0-h5101ec6_17 --> conda-forge::libgcc-ng-11.2.0-h1d223b6_9
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.3.0-hd4cf53~ --> conda-forge::libstdcxx-ng-11.2.0-he4da1e4_9
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex          pkgs/main::_openmp_mutex-4.5-1_gnu --> conda-forge::_openmp_mutex-4.5-1_llvm
#   ca-certificates    pkgs/main::ca-certificates-2021.7.5-h~ --> conda-forge::ca-certificates-2021.5.30-ha878542_0
#   certifi            pkgs/main::certifi-2021.5.30-py38h06a~ --> conda-forge::certifi-2021.5.30-py38h578d9bd_0
#   openssl              pkgs/main::openssl-1.1.1l-h7f8727e_0 --> conda-forge::openssl-1.1.1l-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# libxml2-2.9.12       | 772 KB    | ##################################### | 100%
# jupyter_console-6.4. | 22 KB     | ##################################### | 100%
# libxkbcommon-1.0.3   | 581 KB    | ##################################### | 100%
# vtk-m-1.5.1          | 4.8 MB    | ##################################### | 100%
# libogg-1.3.4         | 206 KB    | ##################################### | 100%
# curl-7.79.1          | 153 KB    | ##################################### | 100%
# glib-tools-2.68.4    | 86 KB     | ##################################### | 100%
# ipywidgets-7.6.5     | 101 KB    | ##################################### | 100%
# xorg-libxext-1.3.4   | 54 KB     | ##################################### | 100%
# libvorbis-1.3.7      | 280 KB    | ##################################### | 100%
# qtpy-1.11.2          | 37 KB     | ##################################### | 100%
# qtconsole-5.1.1      | 89 KB     | ##################################### | 100%
# libnghttp2-1.43.0    | 790 KB    | ##################################### | 100%
# libgfortran-ng-7.5.0 | 22 KB     | ##################################### | 100%
# xorg-xextproto-7.3.0 | 28 KB     | ##################################### | 100%
# libclang-11.1.0      | 19.2 MB   | ##################################### | 100%
# cryptography-3.4.7   | 1.1 MB    | ##################################### | 100%
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# cached-property-1.5. | 4 KB      | ##################################### | 100%
# mysql-common-8.0.25  | 1.6 MB    | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# xorg-kbproto-1.0.7   | 27 KB     | ##################################### | 100%
# h5py-3.2.1           | 1.4 MB    | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# libdeflate-1.7       | 67 KB     | ##################################### | 100%
# libcurl-7.79.1       | 335 KB    | ##################################### | 100%
# libopus-1.3.1        | 255 KB    | ##################################### | 100%
# gst-plugins-base-1.1 | 2.6 MB    | ##################################### | 100%
# lcms2-2.12           | 443 KB    | ##################################### | 100%
# libssh2-1.10.0       | 233 KB    | ##################################### | 100%
# pyqtwebengine-5.12.1 | 175 KB    | ##################################### | 100%
# libholoplaycore-0.1. | 325 KB    | ##################################### | 100%
# ca-certificates-2021 | 136 KB    | ##################################### | 100%
# libopenblas-0.3.12   | 8.2 MB    | ##################################### | 100%
# mysql-libs-8.0.25    | 1.8 MB    | ##################################### | 100%
# rigimol-1.3          | 489 KB    | ##################################### | 100%
# libstdcxx-ng-11.2.0  | 4.2 MB    | ##################################### | 100%
# nss-3.69             | 2.1 MB    | ##################################### | 100%
# libedit-3.1.20191231 | 121 KB    | ##################################### | 100%
# prompt_toolkit-3.0.2 | 4 KB      | ##################################### | 100%
# openssl-1.1.1l       | 2.1 MB    | ##################################### | 100%
# jpeg-9d              | 264 KB    | ##################################### | 100%
# charset-normalizer-2 | 32 KB     | ##################################### | 100%
# hdf4-4.2.15          | 950 KB    | ##################################### | 100%
# jupyterlab_widgets-1 | 130 KB    | ##################################### | 100%
# libblas-3.9.0        | 11 KB     | ##################################### | 100%
# libnetcdf-4.8.1      | 1.4 MB    | ##################################### | 100%
# jupyter-1.0.0        | 6 KB      | ##################################### | 100%
# mtz2ccp4_px-1.0      | 547 KB    | ##################################### | 100%
# libzip-1.8.0         | 126 KB    | ##################################### | 100%
# glib-2.68.4          | 447 KB    | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# jbig-2.1             | 43 KB     | ##################################### | 100%
# libllvm11-11.1.0     | 29.1 MB   | ##################################### | 100%
# pyqt-5.12.3          | 21 KB     | ##################################### | 100%
# gettext-0.19.8.1     | 3.6 MB    | ##################################### | 100%
# bzip2-1.0.8          | 484 KB    | ##################################### | 100%
# widgetsnbextension-3 | 1.8 MB    | ##################################### | 100%
# krb5-1.19.2          | 1.4 MB    | ##################################### | 100%
# libwebp-base-1.2.1   | 845 KB    | ##################################### | 100%
# libgcc-ng-11.2.0     | 889 KB    | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# pymol-2.5.2          | 9.2 MB    | ##################################### | 100%
# zstd-1.5.0           | 490 KB    | ##################################### | 100%
# libtiff-4.3.0        | 668 KB    | ##################################### | 100%
# fontconfig-2.13.1    | 357 KB    | ##################################### | 100%
# _openmp_mutex-4.5    | 5 KB      | ##################################### | 100%
# olefile-0.46         | 32 KB     | ##################################### | 100%
# expat-2.4.1          | 182 KB    | ##################################### | 100%
# libglu-9.0.0         | 413 KB    | ##################################### | 100%
# idna-3.1             | 52 KB     | ##################################### | 100%
# libxcb-1.13          | 395 KB    | ##################################### | 100%
# nspr-4.30            | 233 KB    | ##################################### | 100%
# llvm-openmp-12.0.1   | 2.8 MB    | ##################################### | 100%
# xorg-xproto-7.0.31   | 73 KB     | ##################################### | 100%
# pcre-8.45            | 253 KB    | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# lz4-c-1.9.3          | 179 KB    | ##################################### | 100%
# pyqtchart-5.12       | 257 KB    | ##################################### | 100%
# libgfortran4-7.5.0   | 1.3 MB    | ##################################### | 100%
# pyqt5-sip-4.19.18    | 310 KB    | ##################################### | 100%
# alsa-lib-1.2.3       | 560 KB    | ##################################### | 100%
# dbus-1.13.6          | 572 KB    | ##################################### | 100%
# libiconv-1.16        | 1.4 MB    | ##################################### | 100%
# brotlipy-0.7.0       | 341 KB    | ##################################### | 100%
# pmw-2.0.1            | 496 KB    | ##################################### | 100%
# chardet-4.0.0        | 199 KB    | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# gstreamer-1.18.5     | 2.0 MB    | ##################################### | 100%
# libuuid-2.32.1       | 28 KB     | ##################################### | 100%
# libevent-2.1.10      | 1.1 MB    | ##################################### | 100%
# urllib3-1.26.7       | 100 KB    | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 19 KB     | ##################################### | 100%
# hdf5-1.10.6          | 3.1 MB    | ##################################### | 100%
# numpy-1.21.2         | 6.2 MB    | ##################################### | 100%
# c-ares-1.17.2        | 109 KB    | ##################################### | 100%
# xorg-libx11-1.7.2    | 941 KB    | ##################################### | 100%
# glew-2.1.0           | 647 KB    | ##################################### | 100%
# openjpeg-2.4.0       | 444 KB    | ##################################### | 100%
# qt-5.12.9            | 99.5 MB   | ##################################### | 100%
# requests-2.26.0      | 52 KB     | ##################################### | 100%
# libpq-13.3           | 2.7 MB    | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# pyopenssl-21.0.0     | 48 KB     | ##################################### | 100%
# cached_property-1.5. | 11 KB     | ##################################### | 100%
# lerc-2.2.1           | 213 KB    | ##################################### | 100%
# libev-4.33           | 104 KB    | ##################################### | 100%
# pyqt-impl-5.12.3     | 5.9 MB    | ##################################### | 100%
# libglib-2.68.4       | 3.0 MB    | ##################################### | 100%
# pillow-8.3.2         | 693 KB    | ##################################### | 100%
# certifi-2021.5.30    | 141 KB    | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: | Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
#
# done

# %%
from pymol import cmd
cmd.fragment('ala')
cmd.orient()
cmd.png('/tmp/foo.png', ray=1)
from IPython.display import Image
Image(filename='/tmp/foo.png')

# %%
# open a PyMOL window
import sys
import pymol
_stdouterr = sys.stdout, sys.stderr
pymol.finish_launching(['pymol', '-q'])
sys.stdout, sys.stderr = _stdouterr

# load something into the PyMOL window
from pymol import cmd
cmd.fragment('ala')

# %%
# load something into the PyMOL window
import xmlrpc.client as xmlrpclib
cmd = xmlrpclib.ServerProxy('http://localhost:9123')
cmd.fragment('ala')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_1526/681510699.py in <module>
#       2 import xmlrpc.client as xmlrpclib
#       3 cmd = xmlrpclib.ServerProxy('http://localhost:9123')
# ----> 4 cmd.fragment('ala')
#
# /opt/conda/envs/vina/lib/python3.8/xmlrpc/client.py in __call__(self, *args)
#    1107         return _Method(self.__send, "%s.%s" % (self.__name, name))
#    1108     def __call__(self, *args):
# -> 1109         return self.__send(self.__name, args)
#    1110
#    1111 ##
#
# /opt/conda/envs/vina/lib/python3.8/xmlrpc/client.py in __request(self, methodname, params)
#    1448                         allow_none=self.__allow_none).encode(self.__encoding, 'xmlcharrefreplace')
#    1449
# -> 1450         response = self.__transport.request(
#    1451             self.__host,
#    1452             self.__handler,
#
# /opt/conda/envs/vina/lib/python3.8/xmlrpc/client.py in request(self, host, handler, request_body, verbose)
#    1151         for i in (0, 1):
#    1152             try:
# -> 1153                 return self.single_request(host, handler, request_body, verbose)
#    1154             except http.client.RemoteDisconnected:
#    1155                 if i:
#
# /opt/conda/envs/vina/lib/python3.8/xmlrpc/client.py in single_request(self, host, handler, request_body, verbose)
#    1163         # issue XML-RPC request
#    1164         try:
# -> 1165             http_conn = self.send_request(host, handler, request_body, verbose)
#    1166             resp = http_conn.getresponse()
#    1167             if resp.status == 200:
#
# /opt/conda/envs/vina/lib/python3.8/xmlrpc/client.py in send_request(self, host, handler, request_body, debug)
#    1276         headers.append(("User-Agent", self.user_agent))
#    1277         self.send_headers(connection, headers)
# -> 1278         self.send_content(connection, request_body)
#    1279         return connection
#    1280
#
# /opt/conda/envs/vina/lib/python3.8/xmlrpc/client.py in send_content(self, connection, request_body)
#    1306
#    1307         connection.putheader("Content-Length", str(len(request_body)))
# -> 1308         connection.endheaders(request_body)
#    1309
#    1310     ##
#
# /opt/conda/envs/vina/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1249         else:
#    1250             raise CannotSendHeader()
# -> 1251         self._send_output(message_body, encode_chunked=encode_chunked)
#    1252
#    1253     def request(self, method, url, body=None, headers={}, *,
#
# /opt/conda/envs/vina/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1009         msg = b"\r\n".join(self._buffer)
#    1010         del self._buffer[:]
# -> 1011         self.send(msg)
#    1012
#    1013         if message_body is not None:
#
# /opt/conda/envs/vina/lib/python3.8/http/client.py in send(self, data)
#     949         if self.sock is None:
#     950             if self.auto_open:
# --> 951                 self.connect()
#     952             else:
#     953                 raise NotConnected()
#
# /opt/conda/envs/vina/lib/python3.8/http/client.py in connect(self)
#     920     def connect(self):
#     921         """Connect to the host and port specified in __init__."""
# --> 922         self.sock = self._create_connection(
#     923             (self.host,self.port), self.timeout, self.source_address)
#     924         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /opt/conda/envs/vina/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
#     807         try:
# --> 808             raise err
#     809         finally:
#     810             # Break explicitly a reference cycle
#
# /opt/conda/envs/vina/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     794             if source_address:
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#     798             err = None
#
# OSError: [Errno 99] Cannot assign requested address
